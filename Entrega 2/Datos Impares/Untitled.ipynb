# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 5.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 4.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.7/500.7 KB 5.7 MB/s eta 0:00:00a 0:00:01
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("Eventos copy.csv")

# %%
print(df.to_string())
# Out:
#                           Evento                               Recinto                Artista          Ciudad            Pais Fecha de incio                                        Productora
# 0                      BZRP Tour                Pabellon Max Schmeling           Paulo Londra          BERLIN        ALEMANIA       09-05-20                                Nachhaltige Events
# 1           Como si no importara                    Arena Ludwingsburg                 Emilia    LUDWINGSBURG        ALEMANIA       23-01-21                                      fullevent.de
# 2                  Born this way                          Irving Plaza              Lady Gaga      NUEVA YORK  ESTADOS UNIDOS       12-09-20                                           CSI DMC
# 3                     El Duko2.0                           Thunder Bay                   Duki         ONTARIO          CANADA       29-07-20                                         EventsEye
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 df.unique
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df["Evento"].unique
# Out:
# <bound method Series.unique of 0                 BZRP Tour
# 1      Como si no importara
# 2             Born this way
# 3                El Duko2.0
# 4              LOS APARATOS
#                ...
# 461                      Ye
# 462             Show Forest
# 463             Rio Concert
# 464         R3hab live show
# 465                 Heather
# Name: Evento, Length: 466, dtype: object>
